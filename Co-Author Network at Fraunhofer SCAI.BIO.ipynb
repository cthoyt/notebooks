# %% [markdown]
# The goal of this notebook is to use WikiData's citation and co-author information to generate centrality metrics for Fraunhofer SCAI.BIO. Keep in mind that WikiData is not necessarily complete, so these calculations are only based on the information that is available.

# %%
import sys
import time

import networkx as nx
import pandas as pd
import requests
import SPARQLWrapper as sw

# %%
print(sys.version)
# Out:
# 3.7.3 (default, Mar 27 2019, 09:23:15)
# [Clang 10.0.1 (clang-1001.0.46.3)]

# %%
print(time.asctime())
# Out:
# Sat May 11 14:10:10 2019

# %% [markdown]
# This SPARQL query is borrowed from Scholia.

# %%
query = """
SELECT
  # ?author1 ?author1Label ?image1 ?rgb
  # ?author2 ?author2Label ?image2 
WITH {
  SELECT
    # ?author1 (SAMPLE(?image1_) AS ?image1)
    # ?author2 (SAMPLE(?image2_) AS ?image2)
    (SAMPLE(?rgb_) AS ?rgb)
  WHERE {
    wd:Q1451981 ^wdt:P361* / ^( wdt:P108 | wdt:P1416 | wdt:P463 ) ?author1 , ?author2 . 
    # ?work wdt:P50 ?author1 , ?author2 .

    # Only display co-authorship for certain types of documents
    # Journal and conference articles, books, not (yet?) software
    VALUES ?publication_type { wd:Q13442814 wd:Q571 wd:Q26973022 wd:Q17928402 wd:Q947859 }
    FILTER EXISTS { ?work wdt:P31 ?publication_type . }

    # No self-links.
    FILTER (?author1 != ?author2)
    
    # Images
    OPTIONAL { ?author1 wdt:P18 ?image1_ }
    OPTIONAL { ?author2 wdt:P18 ?image2_ }

    # Coloring of the nodes
    BIND("FFFFFF" AS ?rgb_)
  }
  GROUP BY ?author1 ?author2
} AS %result
WHERE {
  INCLUDE %result
  SERVICE wikibase:label { bd:serviceParam wikibase:language "en,da,de,es,fr,jp,sv,ru,zh".
  }
}
"""

# %% [markdown]
# Get the results. Alternatively, the same code could be used:
#
# ```python
# url = 'https://query.wikidata.org/bigdata/namespace/wdq/sparql'
# results = requests.get(url, params={'query': query, 'format': 'json'}).json()
# ```

# %%
sparql = sw.SPARQLWrapper("https://query.wikidata.org/sparql")
sparql.setQuery(query)
sparql.setReturnFormat(sw.JSON)
results = sparql.query().convert()

# %% [markdown]
# Aggregate the results into a NetworkX graph.

# %%
graph = nx.Graph([
    (result['author1Label']['value'], result['author2Label']['value'])
    for result in results['results']['bindings']
])

# %% [markdown]
# Calculate various centrality metrics and generate a dataframe.

# %%
degrees = dict(nx.degree(graph))
degree_centralities = nx.degree_centrality(graph)
betweenness_centralities = nx.betweenness_centrality(graph)

df = pd.DataFrame(
    [
        (
            name, 
            round(100 * betweenness_centralities[name], 2), 
            round(100 * degree_centralities[name], 2),
            degrees[name],
        )
        for name in sorted(betweenness_centralities, key=betweenness_centralities.get, reverse=True)
    , 
    columns=[
        'Name', 
        'Betweenness Centrality (%)', 
        'Degree Centrality (%)',
        'Degree',
    ],
).set_index('Name')

# %%
df = pd.DataFrame.from_dict(
    {
        name: {   
            'Between': round(100 * betweenness_centralities[name], 2), 
            '': round(100 * degree_centralities[name], 2),
            '': degrees[name],
        }
        for name in sorted(betweenness_centralities, key=betweenness_centralities.get, reverse=True)
    }, 
    orient='index',
)
df
# Out:
#                               0       1   2
# Martin Hofmann-Apitius    44.93  100.00  35
# Daniel Domingo-Fernández  11.71   71.43  25
# Charles Tapley Hoyt        5.43   54.29  19
# Christian Ebeling          4.39   54.29  19
# Alpha Tom Kodamullil       3.00   45.71  16
# Anandhi Iyappan            1.38   37.14  13
# Juliane Fluck              0.94   22.86   8
# Erfan Younesi              0.87   28.57  10
# Stephan Springstubbe       0.73   34.29  12
# Reagon Karki               0.65   34.29  12
# Shweta Bagewadi            0.39   22.86   8
# Michaela Gündel            0.25   17.14   6
# Tamara Raschka             0.13   28.57  10
# Mufassra Naz               0.13   28.57  10
# Mohammed Asif Emon Khan    0.10   28.57  10
# Ashutosh Malhotra          0.07   17.14   6
# Simon Müller               0.00   31.43  11
# Bradley English            0.00   31.43  11
# Colin Birkenbihl           0.00   31.43  11
# Esther Wollert             0.00   20.00   7
# Sandra Spalek              0.00   20.00   7
# Kristian Kolpeja           0.00   20.00   7
# Lingling Xu                0.00   20.00   7
# Rana Aldisi                0.00   20.00   7
# Özlem Muslu                0.00   31.43  11
# Christoph M. Friedrich     0.00    8.57   3
# Marc Zimmermann            0.00    8.57   3
# Josep Marin-Llao           0.00   31.43  11
# Sarah Mubeen               0.00   31.43  11
# Andrej Konotopez           0.00   31.43  11
# Mehdi Ali                  0.00   31.43  11
# Nóra Réka Balzer           0.00   11.43   4
# Anka Güldenpfennig         0.00   11.43   4
# Sumit Madan                0.00   14.29   5
# Shashank Khanna            0.00    8.57   3
# Meemansa Sood              0.00    5.71   2

# %% [markdown]
# The betweenness centrality of an author represents how collaborative they are, i.e., how many different groups of people they have worked with. The degree and degree centrality represents the total number of co-authors, and the normalized total number of co-authors against the author with the highest degree.

# %%
df
# Out:
#                           Betweenness Centrality (%)  Degree Centrality (%)  \
# Name
# Martin Hofmann-Apitius                         44.93                 100.00
# Daniel Domingo-Fernández                       11.71                  71.43
# Charles Tapley Hoyt                             5.43                  54.29
# Christian Ebeling                               4.39                  54.29
# Alpha Tom Kodamullil                            3.00                  45.71
# Anandhi Iyappan                                 1.38                  37.14
# Juliane Fluck                                   0.94                  22.86
# Erfan Younesi                                   0.87                  28.57
# Stephan Springstubbe                            0.73                  34.29
# Reagon Karki                                    0.65                  34.29
# Shweta Bagewadi                                 0.39                  22.86
# Michaela Gündel                                 0.25                  17.14
# Tamara Raschka                                  0.13                  28.57
# Mufassra Naz                                    0.13                  28.57
# Mohammed Asif Emon Khan                         0.10                  28.57
# Ashutosh Malhotra                               0.07                  17.14
# Simon Müller                                    0.00                  31.43
# Bradley English                                 0.00                  31.43
# Colin Birkenbihl                                0.00                  31.43
# Esther Wollert                                  0.00                  20.00
# Sandra Spalek                                   0.00                  20.00
# Kristian Kolpeja                                0.00                  20.00
# Lingling Xu                                     0.00                  20.00
# Rana Aldisi                                     0.00                  20.00
# Özlem Muslu                                     0.00                  31.43
# Christoph M. Friedrich                          0.00                   8.57
# Marc Zimmermann                                 0.00                   8.57
# Josep Marin-Llao                                0.00                  31.43
# Sarah Mubeen                                    0.00                  31.43
# Andrej Konotopez                                0.00                  31.43
# Mehdi Ali                                       0.00                  31.43
# Nóra Réka Balzer                                0.00                  11.43
# Anka Güldenpfennig                              0.00                  11.43
# Sumit Madan                                     0.00                  14.29
# Shashank Khanna                                 0.00                   8.57
# Meemansa Sood                                   0.00                   5.71
#
#                           Degree
# Name
# Martin Hofmann-Apitius        35
# Daniel Domingo-Fernández      25
# Charles Tapley Hoyt           19
# Christian Ebeling             19
# Alpha Tom Kodamullil          16
# Anandhi Iyappan               13
# Juliane Fluck                  8
# Erfan Younesi                 10
# Stephan Springstubbe          12
# Reagon Karki                  12
# Shweta Bagewadi                8
# Michaela Gündel                6
# Tamara Raschka                10
# Mufassra Naz                  10
# Mohammed Asif Emon Khan       10
# Ashutosh Malhotra              6
# Simon Müller                  11
# Bradley English               11
# Colin Birkenbihl              11
# Esther Wollert                 7
# Sandra Spalek                  7
# Kristian Kolpeja               7
# Lingling Xu                    7
# Rana Aldisi                    7
# Özlem Muslu                   11
# Christoph M. Friedrich         3
# Marc Zimmermann                3
# Josep Marin-Llao              11
# Sarah Mubeen                  11
# Andrej Konotopez              11
# Mehdi Ali                     11
# Nóra Réka Balzer               4
# Anka Güldenpfennig             4
# Sumit Madan                    5
# Shashank Khanna                3
# Meemansa Sood                  2
