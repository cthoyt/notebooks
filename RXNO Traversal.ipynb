# %% [markdown]
# # Reaction Ontology (RXNO) Traversal
# The goal of this notebook is to:
# 1. Load the Royal Society of Chemistry's Reaction Ontology, [RXNO](https://raw.githubusercontent.com/rsc-ontologies/rxno/master/rxno.owl), into RDFLib
# 2. Traverse that graph with SPARQL and do some investigating of its structure
# 3. Structure and output the data about individual reactions

# %%
from rdflib import Graph
import pandas as pd
import numpy as np

input_file = "https://raw.githubusercontent.com/rsc-ontologies/rxno/master/rxno.owl"
output_file = "reactions.csv"

# %% [markdown]
# ## Downloading and Parsing RXNO
# Downloading the data and parsing it into RDFLib `Graph` is very easy using RDFLib - no need for the urllib or requests modules.

# %%
g = Graph()
g.parse(input_file, format='xml')
# Out:
# <Graph identifier=Nd3f33fa4027e4248a3c47ff8136ce118 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ## Annotations
# All reactions are represented as classes within RXNO. The reactions themselves are leaves within an irregular classification tree, so they can be isolated by looking for elements with no children `FILTER NOT EXISTS {?x rdfs:subClassOf ?c}`
#
# The first query identifies what types of predicates are used on the entire group of reactions.

# %%
q1 = """
    PREFIX rdf:    <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
    PREFIX foaf:   <http://xmlns.com/foaf/0.1/> 
    PREFIX obo:    <http://purl.obolibrary.org/obo/>
    select distinct ?predicate
    where { 
        # ?reaction ?predicate ?object .
        # ?reaction rdfs:subClassOf ?o .
        # ?reaction oboInOwl:id ?reaction_id .
        FILTER NOT EXISTS { ?x rdfs:subClassOf ?reaction }   
        FILTER regex(?reaction_id, "^RXNO")
    } 
"""
res1 = g.query(q1)
pd.DataFrame(list(res1), columns=("predicate",))
# Out:
#                                             predicate
# 0     http://www.w3.org/2000/01/rdf-schema#subClassOf
# 1     http://www.geneontology.org/formats/oboInOwl#id
# 2     http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 3          http://www.w3.org/2000/01/rdf-schema#label
# 4   http://www.geneontology.org/formats/oboInOwl#h...
# 5          http://purl.obolibrary.org/obo/IAO_0000115
# 6   http://www.geneontology.org/formats/oboInOwl#h...
# 7        http://www.w3.org/2000/01/rdf-schema#comment
# 8   http://www.geneontology.org/formats/oboInOwl#h...
# 9   http://www.geneontology.org/formats/oboInOwl#c...
# 10  http://www.geneontology.org/formats/oboInOwl#c...
# 11     http://purl.obolibrary.org/obo/rxno.obo#SMIRKS
# 12  http://www.geneontology.org/formats/oboInOwl#h...
# 13  http://www.geneontology.org/formats/oboInOwl#h...
# 14      http://www.w3.org/2002/07/owl#equivalentClass
# 15  http://www.geneontology.org/formats/oboInOwl#h...
# 16  http://www.geneontology.org/formats/oboInOwl#h...

# %% [markdown]
# ## SMIRKS
# [SMIRKS](http://www.daylight.com/dayhtml/doc/theory/theory.smirks.html) is one of the reaction transformation languages defined by Daylight as an extension to SMILES. Some reactions have SMIRKS annotated to them, but most don't. The process of filling in the gaps will take quite a bit of manual effort. Below is a list of all of the reactions with SMIRKS annotations already in RXNO.

# %%
#http://purl.obolibrary.org/obo/rxno.obo#SMIRKS
q2 = """
    select ?label ?smirks
    where {
        # ?s rxno:SMIRKS ?smirks .
        # ?s rdfs:label ?label .
    }
"""
res2 = g.query(q2)
pd.DataFrame(list(res2), columns=("label", "smirks"))
# Out:
#                              label  \
# 0                  Scholl reaction
# 1     Paal-Knorr pyrrole synthesis
# 2           Paternò–Büchi reaction
# 3         Demko-Sharpless reaction
# 4              Tishchenko reaction
# 5              Crabbé homologation
# 6   Paal-Knorr thiophene synthesis
# 7                 Michael addition
# 8              Hofmann elimination
# 9             Diels-Alder reaction
# 10          Arndt-Eistert reaction
# 11                 Wittig reaction
# 12      Paal-Knorr furan synthesis
# 13              Mumm rearrangement
# 14       Baeyer-Villiger oxidation
# 15    Rosenmund-von Braun reaction
# 16                    ene reaction
# 17                 Perkin reaction
# 18        Friedel-Crafts acylation
# 19                   diazotisation
# 20            Reformatsky reaction
# 21        nitro reduction to amine
# 22                 Stille coupling
# 23       Schotten-Baumann reaction
# 24              conjugate addition
# 25            acyloin condensation
# 26            Clemmensen reduction
# 27     acetoacetic ester synthesis
# 28                Mannich reaction
#
#                                                smirks
# 0                             [c:1].[c:2]>>[c:1][c:2]
# 1   O=[C:1]-[C:2]-[C:3]-[C:4]=O.[N:5]>>[n:5]1[c:1]...
# 2     [C:1]=[O:2].[C:3]=[C:4]>>[C:1]1[O:2][C:3][C:4]1
# 3   [#6,S,N;H0:1][C:2]#[N:3].[Na+].[N-:4]=[N+:5]=[...
# 4                [C:1](=O).[C:2](=O)>>[C:1](=O)O[C:2]
# 5              [C:1]=[C:2].[C:3]=O>>[C:1]=[C:2]=[C:3]
# 6   O=[C:1]-[C:2]-[C:3]-[C:4]=O.S=P13SP2(=S)SP(=S)...
# 7   [C:1].[C:2]=[C:3][C:4]=[O:5]>>[C:1][C:2][C:3][...
# 8   N1[C:2][C:3][C:4][C:5][C:6]1[C:7]>>[C:2]=[C:3]...
# 9   [C:1]=[C:2][C:3]=[C:4].[C:5]=[C:6]>>[C:1]1[C:2...
# 10                    [#6:1]C(=O)O>>[#6:1][CH2]C(=O)O
# 11                      [C:1]=O.[C:3][P]>>[C:1]=[C:3]
# 12  O=[C:1]-[C:2]-[C:3]-[C:4]=O>>o1[c:1][c:2][c:3]...
# 13  [C:1][N:2]=[C:3]([C:4])[O:5][C:6](=[O:7])[C:8]...
# 14          [C:1][C:2](=O)[C:3]>>[C:1]O[C:2](=O)[C:3]
# 15  [c:1][F,Cl,Br,I].[Cu][C:2]#[N:3]>>[c:1][C:2]#[...
# 16  [C:1]=[C:2][C:3][H:4].[*:5]=[*:6]>>[C:3]=[C:2]...
# 17                 [c:1][C:2](=O)O>>[c:1][C:2]=C(=O)O
# 18                [c:1].[C:2]=[O:3]>>[c:1][C:2]=[O:3]
# 19                        [c:1][N:2]>>[c:1][N:2]=[N+]
# 20  [C:1]=[O:2].[F,Cl,Br,I][C:3][C:4](=[O:5])[O:6]...
# 21                            [N:1](=O)O>>[N&X3;H2:1]
# 22   [Sn][C:1].[C:2][Cl,Br,I:3]>>[C:1][C:2].[Sn][*:3]
# 23      [C:1][N,O].[C:2](=[O:3])Cl>>[O:3]=[C:2]O[C:1]
# 24  [*:1].[C:2]=[C:3][C:4]=[O:5]>>[*:1][C:2][C:3][...
# 25  [C:1][C:2](=O)OC.[C:4][C:3](=O)OC>>[C:1][C:2](...
# 26                      [C:1]=O.[Zn].[Hg].[Cl]>>[C:1]
# 27  C[C:2](=O)[C:1][C:3](=O)OC.[C:4][F,Cl,Br,I]>>C...
# 28  [N:1].[C:2]=O.[C:3][C:4](=O)[C:5]>>[N:1][C:2][...

# %% [markdown]
# ## Bringing It All Together
# Annotate the id, label, parent's label, description, and smirks to each reaction

# %%
q3 = """
    select distinct ?rid ?label ?parent ?des ?smirks
    where { 
        # ?c rdfs:subClassOf ?o .
        # ?o rdfs:label ?parent .
        # ?c rdfs:label ?label .
        # ?c oboInOwl:id ?rid .
        # ?c obo:IAO_0000115 ?des .
        OPTIONAL { ?c rxno:SMIRKS ?smirks}
        FILTER NOT EXISTS { ?x rdfs:subClassOf ?c }   
        FILTER regex(?rid, "^RXNO")
    } 
"""
res3 = g.query(q3)
df = pd.DataFrame(list(res3), columns=("id", "label", "parent_label", "description", "smirks"))
df.head()
# Out:
#              id                         label  \
# 0  RXNO:0000451     aldehyde Sakurai reaction
# 1  RXNO:0000026        Beckmann rearrangement
# 2  RXNO:0000447                 Duff reaction
# 3  RXNO:0000061  Mukaiyama aldol condensation
# 4  RXNO:0000193               Hiyama coupling
#
#                            parent_label  \
# 0  Sakurai reaction, aldehyde or ketone
# 1                    rearrangement step
# 2                           formylation
# 3                    aldol condensation
# 4       carbon-carbon coupling reaction
#
#                                          description smirks
# 0  A carbon-carbon coupling reaction in which an ...   None
# 1  A rearrangement where an oxime rearranges to f...   None
# 2  Formylation of a phenol or aromatic amine with...   None
# 3  An aldol condensation between an aldehyde or k...   None
# 4  A carbon-carbon coupling reaction where an org...   None

# %%
df.to_csv(output_file)
