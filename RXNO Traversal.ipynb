# %% [markdown]
# # RXNO Traversal
# The goal of this notebook is to:
# 1. Load the Royal Society of Chemistry's Reaction Ontology, [RXNO](https://raw.githubusercontent.com/rsc-ontologies/rxno/master/rxno.owl), into RDFLib
# 2. Traverse that graph with SPARQL
# 3. Structure the data about individual reactions
# 4. Output to CSV or relational database

# %%
import rdflib
from rdflib import Graph
import pandas as pd
import numpy as np

input_file = "https://raw.githubusercontent.com/rsc-ontologies/rxno/master/rxno.owl"
output_file = "reactions.csv"

# %% [markdown]
# Download the data and parse into RDFLib `Graph`

# %%
g = Graph()
g.parse(input_file, format='xml')
# Out:
# <Graph identifier=N0b52165575f44a818c5bd311d08c4cd7 (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# Traverse the data to find only classes that don't have any subclasses

# %%
q = """
    PREFIX  rdf:    <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
    PREFIX  foaf:   <http://xmlns.com/foaf/0.1/> 
    PREFIX obo:    <http://purl.obolibrary.org/obo/>
    select distinct ?rid ?label ?parent ?des
    where { 
        # ?c rdfs:subClassOf ?o .
        # ?o rdfs:label ?parent .
        # ?c rdfs:label ?label .
        # ?c oboInOwl:id ?rid .
        # ?c obo:IAO_0000115 ?des .
        FILTER NOT EXISTS { ?x rdfs:subClassOf ?c }   
        FILTER regex(?rid, "^RXNO")
    } 
"""

res = g.query(q)

# %% [markdown]
# Wrangle the results into a Pandas DataFrame

# %%
df = pd.DataFrame(list(res), columns=("id", "name", "parent", "details"))
df
# Out:
#                id                                             name  \
# 0    RXNO:0000276                                  Aufbau reaction
# 1    RXNO:0000350                       alkyne reduction to alkane
# 2    RXNO:0000183                                  Perkow reaction
# 3    RXNO:0000146                             Corey-Fuchs reaction
# 4    RXNO:0000208                   aromatic Claisen rearrangement
# 5    RXNO:0000213                          Sakurai reaction, enone
# 6    RXNO:0000040                                 Ullmann reaction
# 7    RXNO:0000538                                 Chugaev reaction
# 8    RXNO:0000159                          Doebner-Miller reaction
# 9    RXNO:0000419                         phthalimide deprotection
# 10   RXNO:0000305                    seleno-Pummerer rearrangement
# 11   RXNO:0000275                     Stork-Crabtree hydrogenation
# 12   RXNO:0000363             amide to imidoyl chloride conversion
# 13   RXNO:0000311                             Tsuji-Trost reaction
# 14   RXNO:0000408                               Appel chlorination
# 15   RXNO:0000477                               Rupe rearrangement
# 16   RXNO:0000506                                    Nef synthesis
# 17   RXNO:0000143          Sharpless asymmetric aminohydroxylation
# 18   RXNO:0000457               molecular ring expansion objective
# 19   RXNO:0000064                         Fischer indole synthesis
# 20   RXNO:0000535                                Bradsher reaction
# 21   RXNO:0000441                molecular rearrangement objective
# 22   RXNO:0000014                                Grignard reaction
# 23   RXNO:0000451                        aldehyde Sakurai reaction
# 24   RXNO:0000415      haloethanoate ester-ketone Darzens reaction
# 25   RXNO:0000082                                Goldberg reaction
# 26   RXNO:0000153                    Johnson-Claisen rearrangement
# 27   RXNO:0000403                        Pinner triazine synthesis
# 28   RXNO:0000088                                 Negishi coupling
# 29   RXNO:0000023                        Koerner-Contardi reaction
# ..            ...                                              ...
# 465  RXNO:0000065                            Dieckmann cyclisation
# 466  RXNO:0000172          Schmidt rearrangement, tertiary alcohol
# 467  RXNO:0000029                           oxy-Cope rearrangement
# 468  RXNO:0000216                           imine Sakurai reaction
# 469  RXNO:0000055                         Vilsmeier-Haack reaction
# 470  RXNO:0000147                                 Emde degradation
# 471  RXNO:0000384  cyclic alpha-haloketone Favorskii rearrangement
# 472  RXNO:0000032                                 Mannich reaction
# 473  RXNO:0000270   copper(I)-catalyzed azide-alkyne cycloaddition
# 474  RXNO:0000459                      acetoacetic ester synthesis
# 475  RXNO:0000139                              Gattermann reaction
# 476  RXNO:0000418                           phthalimide protection
# 477  RXNO:0000474                                 Auwers synthesis
# 478  RXNO:0000281                                alkyne metathesis
# 479  RXNO:0000422                           Gattermann bromination
# 480  RXNO:0000382                           Demjanov rearrangement
# 481  RXNO:0000092                         aza-Diels-Alder reaction
# 482  RXNO:0000354                               benzylic oxidation
# 483  RXNO:0000357                             N-acylation to amide
# 484  RXNO:0000381                 Tiffeneau-Demjanov rearrangement
# 485  RXNO:0000378                   intramolecular Scholl reaction
# 486  RXNO:0000087                                  Barton reaction
# 487  RXNO:0000219                      crossed Cannizzaro reaction
# 488  RXNO:0000126                                 Doebner reaction
# 489  RXNO:0000420                       Kröhnke pyridine synthesis
# 490  RXNO:0000328                                 silyl protection
# 491  RXNO:0000371                                  Griess reaction
# 492  RXNO:0000137                             Sonogashira coupling
# 493  RXNO:0000157                                     Nef reaction
# 494  RXNO:0000391                         Knorr pyrazole synthesis
#
#                                       parent  \
# 0                    polymerisation reaction
# 1                              hydrogenation
# 2        molecular skeleton joining reaction
# 3                          chain lengthening
# 4                         rearrangement step
# 5                           Sakurai reaction
# 6        carbon-carbon homocoupling reaction
# 7    molecular skeleton elimination reaction
# 8                fused-ring-system formation
# 9                   amino group deprotection
# 10                    Pummerer rearrangement
# 11                    addition reaction step
# 12             functional group modification
# 13           carbon-carbon coupling reaction
# 14                        Appel halogenation
# 15                        rearrangement step
# 16       molecular skeleton joining reaction
# 17                    addition reaction step
# 18        molecular transformation objective
# 19                          indole synthesis
# 20               fused-ring-system formation
# 21        molecular transformation objective
# 22       molecular skeleton joining reaction
# 23      Sakurai reaction, aldehyde or ketone
# 24                          Darzens reaction
# 25                aromatic substitution step
# 26           [3,3]-sigmatropic rearrangement
# 27                        triazine synthesis
# 28           carbon-carbon coupling reaction
# 29                aromatic substitution step
# ..                                       ...
# 465             ring formation reaction step
# 466    molecular skeleton insertion reaction
# 467                       rearrangement step
# 468                         Sakurai reaction
# 469          carbon-carbon coupling reaction
# 470                        cleaving reaction
# 471                  Favorskii rearrangement
# 472      molecular skeleton joining reaction
# 473                      [3+2] cycloaddition
# 474      molecular skeleton joining reaction
# 475                              formylation
# 476                   amino group protection
# 477                       oxacycle synthesis
# 478                 multiple-bond metathesis
# 479                  Gattermann halogenation
# 480                        substitution step
# 481              hetero-Diels-Alder reaction
# 482                                oxidation
# 483                              N-acylation
# 484                       rearrangement step
# 485                          Scholl reaction
# 486                       rearrangement step
# 487            functional group modification
# 488                      quinoline synthesis
# 489                       pyridine synthesis
# 490                             O-silylation
# 491                            diazotisation
# 492      molecular skeleton joining reaction
# 493            functional group modification
# 494           molecular dehydration reaction
#
#                                                details
# 0    The insertion of alkenes (usually ethene) into...
# 1    A hydrogenation reaction where an alkyne is re...
# 2    The reaction between an alpha-halocarbonyl com...
# 3    A homologation reaction of an aldehyde to yiel...
# 4    The [3,3]-sigmatropic rearrangement, and subse...
# 5    A carbon-carbon coupling reaction in which an ...
# 6    A carbon-carbon homocoupling reaction of an ar...
# 7    Elimination of a water molecule from a seconda...
# 8    The formation of a quinoline from a primary ar...
# 9    Conversion of a phthalimide into the correspon...
# 10   The conversion of a selenoxide with an alpha-h...
# 11   A hydrogenation in which a metal-ligating grou...
# 12   A functional group modification where an amide...
# 13   A carbon-carbon coupling reaction in which a n...
# 14   Conversion of an alcohol to an alkyl chloride ...
# 15   Rearrangement of a propargyl alcohol to an alp...
# 16   Reaction of an aldehyde or ketone with a sodiu...
# 17   The aminohydroxylation of an alkene to give a ...
# 18   A molecular transformation objective that is s...
# 19   Reaction of an aldehyde or ketone with a pheny...
# 20   Reaction of an ortho-acyldiarylmethane, cataly...
# 21   A molecular transformation specification that ...
# 22   A carbon-carbon coupling reaction where a Grig...
# 23   A carbon-carbon coupling reaction in which an ...
# 24   A coupling of a ketone with an alpha-haloethan...
# 25   A coupling reaction in which an acetanilide is...
# 26   The coupling and subsequent [3,3]-sigmatropic ...
# 27   Reaction of aryl amidines or halogenated aliph...
# 28   A carbon-carbon coupling reaction between an o...
# 29   An aromatic substitution reaction where an ary...
# ..                                                 ...
# 465  An intramolecular cyclisation of a diester to ...
# 466  The reaction of a tertiary alcohol with hydraz...
# 467  A [3,3]-sigmatropic rearrangement of a 3-hydro...
# 468  A carbon-carbon coupling reaction in which an ...
# 469  A formylation of an activated arene with a dis...
# 470  A reduction of a quaternary ammonium salt cont...
# 471  Base-catalysed rearrangement of a cyclic alpha...
# 472  A carbon-carbon coupling reaction where ammoni...
# 473  A [3+2] cycloaddition reaction between an azid...
# 474  A carbon-carbon coupling reaction between a be...
# 475  The formylation of an arene with hydrogen cyan...
# 476  Protection of a primary amino group by reactio...
# 477  Ring expansion of a 2-bromo-2-(alpha-bromobenz...
# 478  A joining reaction in which two carbon-carbon ...
# 479  A Gattermann halogenation where the aryl diazo...
# 480  Substitution reaction of a primary amine via d...
# 481  A Diels-Alder reaction between a diene and an ...
# 482  An oxidation reaction where a carbon centre bo...
# 483  An acylation reaction where a nitrogen atom is...
# 484  Rearrangement of a beta-amino alcohol to yield...
# 485  Scholl reaction within a single molecule to fo...
# 486  The photolytic oxidation of a nitrate ester to...
# 487  The reaction between two different non-enolisa...
# 488  The reaction between an aromatic amine, an ald...
# 489  Condensation of a 1,5-diketone with ammonium a...
# 490  A hydroxyl group protection where the hydroxyl...
# 491  A diazotisation that proceeds by the addition ...
# 492  A carbon-carbon coupling reaction where a term...
# 493  The conversion of a primary nitroalkane or sec...
# 494  Synthesis of a pyrazole by condensation of a 1...
#
# [495 rows x 4 columns]

# %% [markdown]
# Output Structured Data to CSV

# %%
df.to_csv(output_file)
