# %% [markdown]
# # Getting Started
#
# This course will follow the full stack of data analysis and use multiple layers of technology.
#
# - Eclipse + PyDev
# - MySQL
# - Git + GitHub
# - Python3
#     - pymysql
#     - NetworkX
#     - Pandas
#     - Jupyter Notebook
#     - Scikit Learn

# %% [markdown]
# ## Python Packages
#
# ### Install Anaconda
#
# Anaconda is a self-contained python installation that comes pre-packaged with lots of powerful packages and tools.
#
# 1. Download and install Anaconda3 from https://www.continuium.io/ to C:\anaconda\
# 2. On windows, python should be added to the path automatically. Restart all command prompts to reload `PATH`.
# 3. In the command prompt, run `pip install --upgrade jupyter pandas sklearn networkx pymysql`

# %% [markdown]
# ## MySQL
#
# 1. Download and install from http://dev.mysql.com/downloads/installer/
# 2. Add `C:\Program Files\MySQL\MySQL Server 5.7\bin` to `PATH`. On Windows 10:
#     1. System Settings -> About -> System Info -> Advanced System Settings -> Environment Variables
#     2. Click PATH and then Edit
#     3. Click New and add `C:\Program Files\MySQL\MySQL Server 5.7\bin`
# 3. In command prompt, check proper installation by running `mysql -u username -p`
# 4. Install MySQL Workbench from https://www.mysql.de/products/workbench/

# %% [markdown]
# ## GitHub
#
# ### Create an account
#
# 1. Create GitHub account ([tutorial](https://help.github.com/articles/signing-up-for-a-new-github-account/))
# 2. Email your username to the course instructors to be added to the BIT-LSI organization
# 3. Navigate to the [organization page](https://github.com/bit-lsi) and accept the organization invite on the banner at the top of the page.
#
# ### Making a Team
#
# - We may use the team feature within the course
#
# ### Downloading the GitHub Desktop Client
#
# 1. Download and install the GitHub Desktop client. ([tutorial](https://help.github.com/desktop/guides/getting-started/authenticating-to-github/#platform-mac)) from https://desktop.github.com/
# 2. Follow steps on  to sign in and set up
# 3. Configure your git preferences so commits have your name and email. ([tutorial](https://help.github.com/desktop/guides/getting-started/configuring-git-for-github-desktop/))
#
#
# ### Downloading the Test Repository
#
# 1. Navigate to https://github.com/bit-lsi/bug-free-eureka.git
# 2. Click "Download with GitHub Desktop Client"
# 3. Save to `c:\git`
#
# ### Get Acquanited with Git and GitHub
# - read the [GitHub Tutorial](https://guides.github.com/activities/hello-world/)

# %% [markdown]
# ## Java
#
# 1. Download and install the latest version of Java 1.8 JDK from http://www.oracle.com/technetwork/java/javase/downloads/

# %% [markdown]
# ## Eclipse and PyDev
#
#
# ### Install Eclipse
#
# 1. Download and install the Eclipse IDE from https://www.eclipse.org/downloads/. The "Eclipse IDE for Java Developers" option is generally the best to start with.
# 2. On first start, choose `C:\workspace` as your workspace. Click the radio box to use this as the default workspace.
#
#
# ### Install PyDev Extension
#
# This extension facilitates using eclipse with the python language.
#
# 1. Follow the instructions at http://www.pydev.org/manual_101_install.html to download and install from within the Eclipse software manager. Eclipse might ask questions to install unsigned content, this is okay.
# 2. Restart eclipse.
# 3. Later, we will automatically configure which python interpreter PyDev will use. You can optionally set it up yourself here if your installation isn't standard.
#     - Preferences -> PyDev -> Interpreters -> Python Interpreter
#     - in terminal type `which python3` and copy paste the output into "Interpreter Executable"
#     - select for the right python interpreter. for mac users, don't use system python. bad idea.
#
# ### Install EGit Extension
#
# Eclipse can play nice with git and GitHub using the EGit extension
#
# 1. Install EGit extension ([tutorial](http://www.vogella.com/tutorials/EclipseGit/article.html#eclipseinstallationgit))
#
# ### Importing Git Project
#
# 1. File -> Import -> Git -> Projects from Git -> Existing Local Repository
# 2. Click add and navigate to C:\git\bug-free-eureka
# 3. Click the box and finish
# 4. Select "Import as General Project"
#
# Resources:
# - http://stackoverflow.com/questions/6760115/importing-a-github-project-into-eclipse
#
# ### Test
# - Create a file within the project called `secrets.json`
# - Fill the file with the connection parameters as follows:
# ```json
# {
# 	"test_db": {
# 		"host": "localhost",
# 		"db": "mysql",
# 		"user": "YOUR USERNAME",
# 		"password": "YOUR PASSWORD",
# 		"port": 3306
# 	}
# }
# ```
# - Open `test.py` and run it with the big green plus button.
# - Click quick configuration of python interpreter

# %% [markdown]
# # Outline
#
# ## Goals
#
# - make sense out of data
#
# ## Software Development & Best Practices
#
# - pair programming
# - code review
# - pep8 style guide
# - proper testing
# - presentations
#
#
# # Tentative Schedule
#
# ## Day 1
#
# - Class Overview
# - Python Review
# - Object Oriented Programming Review
# - SQL Review
#
# ## Day 2
#
# ## Day 3
#
# ## Day 4
#
# ## Day 5
#
# ## Day 6
#
# ## Day 7
#
# ## Day 8
#
# ## Day 9
#
# ## Day 10
