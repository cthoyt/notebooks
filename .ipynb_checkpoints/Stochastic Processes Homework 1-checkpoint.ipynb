# %% [markdown]
# #Statistics and Stochastic Processes: Homework 1 Problem 10

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
np.random.seed(seed=126)
n_samples = 20000

# %% [markdown]
# ##Part A: Build Simulators from Uniform(0, 1)

# %%
u = np.random.uniform(low=0, high=1, size=n_samples)

plt.hist(u)
plt.title("Numpy Sampling from Uniform(0, 1)")
plt.show()

# %%
a, b = 0, np.pi
T = (b - a) * u + a

plt.hist(T)
plt.title(r"Calculated: $T = 2\pi * u$ ~ Uniform(0, $2\pi$)")
plt.show()

# %%
U = np.negative(np.log(1 - u))

plt.hist(U)
plt.title(r"Calculated: $U = -\ln(1-T)$ ~ Exponential(1) ")
plt.show()

# %%
X = np.sqrt(2 * U) * np.cos(T)

plt.hist(X)
plt.title("Calculated: $X = \sqrt{2U}\cos(T)$")
plt.show()

# %%
Y = np.sqrt(2 * U) * np.sin(T)

plt.hist(Y)
plt.title("Calculated: $Y = \sqrt{2U}\sin(T)$")
plt.show()

# %% [markdown]
# ##Part B: Use of Numpy's Simulators

# %%
plt.hist(np.random.uniform(0, 2*np.pi, size=n_samples))
plt.title(r"Numpy Sampling from Uniform(0, $2\pi$)")
plt.show()

# %%
plt.hist(np.random.exponential(1, size=n_samples))
plt.title("Numpy Sampling from Exponential(1)")
plt.show()

# %%
plt.hist(np.random.normal(0, 1, size=n_samples))
plt.title("Numpy Sampling from Normal(0, 1)")
plt.show()
